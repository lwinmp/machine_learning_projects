# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Out goal is to analyze amazon sale based on customers' ratings

# %%
df = pd.read_csv('amazon.csv')
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.describe(include='all')
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna(subset=['rating_count'])

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['rating'], bins=10, kde=True)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Frequence")
plt.show()

# %%
plt.figure(figsize=(45,20))
sns.histplot(df['discount_percentage'], bins=20, kde=True)
plt.title("Discount Distribution")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['actual_price'], bins=30, kde=True)
plt.title("Price Distribution")
plt.show()

# %%
df.sort_values(by='actual_price').tail()
# Out:
#       product_id                                       product_name  \
# 208   B095244Q22  MYVN LTG to USB for Fast Charging & Data Sync ...
# 760   B01MF8MB65  boAt Bassheads 225 in Ear Wired Earphones with...
# 93    B09VT6JKRP  Lapster USB 3.0 A to Micro B SuperSpeed for ha...
# 1370  B08K36NZSV  KONVIO NEER 10 Inch Spun Filter (PP SPUN) Cart...
# 1298  B08SKZ2RMG  Demokrazy New Nova Lint Cum Fuzz Remover for A...
#
#                                                category discounted_price  \
# 208   Computers&Accessories|Accessories&Peripherals|...             ₹252
# 760   Electronics|Headphones,Earbuds&Accessories|Hea...             ₹699
# 93    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 1370  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹499
# 1298  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...             ₹475
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
df[['actual_price', 'discounted_price']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   actual_price      1463 non-null   object
#  1   discounted_price  1463 non-null   object
# dtypes: object(2)
# memory usage: 34.3+ KB

# %%
df = df[df["rating"] != "|"]

# %%
df['rating'] = df['rating'].astype(float)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype(float)

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage  rating  rating_count  \
# 0       ₹1,099                 64%     4.2       24269.0
# ...

# %%
median_count = df['rating_count'].median()
df['rating_count'] = df['rating_count'].fillna(median_count)

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage  rating  rating_count  \
# 0       ₹1,099                 64%     4.2       24269.0
# ...

# %%
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
df['discount_percentage'] = df['discount_percentage'].str.replace('%', '').astype(float)

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1462 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1462 non-null   object
#  1   product_name         1462 non-null   object
#  2   category             1462 non-null   object
#  3   discounted_price     1462 non-null   float64
#  4   actual_price         1462 non-null   float64
#  5   discount_percentage  1462 non-null   float64
#  6   rating               1462 non-null   float64
#  7   rating_count         1462 non-null   float64
#  8   about_product        1462 non-null   object
#  9   user_id              1462 non-null   object
#  10  user_name            1462 non-null   object
#  11  review_id            1462 non-null   object
#  12  review_title         1462 non-null   object
#  13  review_content       1462 non-null   object
#  14  img_link             1462 non-null   object
# ...

# %%
df['rating'].unique()
# Out:
# array([4.2, 4. , 3.9, 4.1, 4.3, 4.4, 4.5, 3.7, 3.3, 3.6, 3.4, 3.8, 3.5,
#        4.6, 3.2, 5. , 4.7, 3. , 2.8, 3.1, 4.8, 2.3, 2. , 2.6, 2.9])

# %%
df['rating_count'].unique()
# Out:
# array([24269., 43994.,  7928., ...,   468.,  8031.,  6987.])

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['rating_count'] = df['rating_count'].str.replace(',', '').astype(float)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df['rating_count'].unique()

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df['rating'].unique()
# Out:
# array([4.2, 4. , 3.9, 4.1, 4.3, 4.4, 4.5, 3.7, 3.3, 3.6, 3.4, 3.8, 3.5,
#        4.6, 3.2, 5. , 4.7, 3. , 2.8, 3.1, 4.8, 2.3, 2. , 2.6, 2.9])

# %%
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce')

# %%
correlation = df['rating'].corr(df['rating_count'])
print(f"Mathematical Correlation between Rating and Sales Proxy: {correlation:.4f}")
# Out:
# Mathematical Correlation between Rating and Sales Proxy: 0.1022

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
fig, axes = plt.subplots(1, 2, figsize=(10,6))
sns.histplot(df['rating'], bins=30, kde=True, color='blue', ax=axes[0])
axes[0].set_title('Distribution of Product Rating', fontsize=12)
axes[0].set_xlabel('Rating (1-5 Stars)')
axes[0].set_ylabel('No: of Products')

sns.scatterplot(x='rating', y='rating_count', data=df, alpha=0.5, color='orange', ax=axes[1])
axes[1].set_title('Do higher ratings mean more sales?', fontsize=12)
axes[1].set_xlabel('Product Rating')
axes[1].set_ylabel('Rating Count')

plt.tight_layout()
plt.show()

correlation = df['rating'].corr(df['rating_count'])
print(f"Mathematical Correlation between Rating and Sales Proxy: {correlation:.4f}")
# Out:
# Mathematical Correlation between Rating and Sales Proxy: 0.1022

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
df['main_category'] = df['category'].str.split('|').str[0]
category_stats = df.groupby('main_category').agg(
    avg_rating = ('rating', 'mean'),
    total_reviews = ('rating_count', 'sum'),
    product_count = ('product_id', 'count')
).sort_values('total_reviews', ascending=False)
category_stats.head(5)
# Out:
#                        avg_rating  total_reviews  product_count
# main_category
# Electronics              4.081749     15778848.0            526
# Computers&Accessories    4.155654      7728689.0            451
# Home&Kitchen             4.040716      2990077.0            447
# OfficeProducts           4.309677       149675.0             31
# MusicalInstruments       3.900000        88882.0              2

# %%
sns.scatterplot(x='discount_percentage', y='rating', data=df, alpha=0.5)
# Out:
# <Axes: xlabel='discount_percentage', ylabel='rating'>

# %%
sns.scatterplot(x='discounted_price', y='rating', data=df, alpha=0.5)
# Out:
# <Axes: xlabel='discounted_price', ylabel='rating'>

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
df['rating_tier'] = pd.cut(df['rating'], bins=[1,2,3,4,5], labels=['1-2', '2-3', '3-4', '4-5'])
ax =df.groupby('rating_tier')['rating_count'].mean().plot(kind='bar')

ax.set_title('Average Reviews by Rating Tier', fontsize=12)
ax.set_xlabel('Rating Tier', fontsize=12)
ax.set_ylabel('Rating Count', fontsize=12)
# Out:
# /var/folders/0t/tlg8p4n91y1g2zyg12tmx_n00000gn/T/ipykernel_46960/2388231763.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ax =df.groupby('rating_tier')['rating_count'].mean().plot(kind='bar')
# Text(0, 0.5, 'Rating Count')

# %%
#Checking what are top rated products
top_product = df[df['rating'] >= 4.5].sort_values('rating_count', ascending=False).head(10)
top_product[['product_name', 'rating', 'rating_count', 'discounted_price', 'discount_percentage']]
# Out:
#                                            product_name  rating  rating_count  \
# 864   SanDisk Extreme SD UHS I 64GB Card for 4K Vide...     4.5      205052.0
# 40    AmazonBasics USB 2.0 Cable - A-Male to B-Male ...     4.5      107687.0
# 852   AmazonBasics USB 2.0 Cable - A-Male to B-Male ...     4.5      107686.0
# 810   Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...     4.5       92925.0
# 212   AmazonBasics USB 2.0 Extension Cable for Perso...     4.5       74977.0
# 30    AmazonBasics USB 2.0 - A-Male to A-Female Exte...     4.5       74976.0
# 802   AmazonBasics USB 2.0 - A-Male to A-Female Exte...     4.5       74976.0
# 734   Logitech M235 Wireless Mouse, 1000 DPI Optical...     4.5       54405.0
# 1145  Swiffer Instant Electric Water Heater Faucet T...     4.8       53803.0
# 625   Seagate Expansion 1TB External HDD - USB 3.0 f...     4.5       50810.0
#
#       discounted_price  discount_percentage
# 864              939.0                 48.0
# ...

# %%
df['discounted_price'].corr(df['rating_count'])
# Out:
# -0.027303809000969865

# %%
df['discount_percentage'].corr(df['rating_count'])
# Out:
# 0.011294393293435052

# %%
#Low correlation - so lets predict future rating count based on current rating, price, and discounts

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
from sklearn.model_selection import train_test_split
df_model = df[['rating', 'actual_price', 'discounted_price','discount_percentage', 'rating_count']].dropna()

# %%
X = df_model.drop('rating_count', axis=1) #input
y = df_model['rating_count'] #target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f"R2 Score: {r2_score(y_test, y_pred):.4f}")
print(f"MAE Score: {mean_absolute_error(y_test, y_pred):.4f}")
# Out:
# R2 Score: 0.0047
# MAE Score: 19853.0852

# %%
from sklearn.ensemble import RandomForestRegressor

RFR = RandomForestRegressor(n_estimators=100, random_state=42)
RFR.fit(X_train, y_train)
y_pred = RFR.predict(X_test)

print(f"R2 Score: {r2_score(y_test, y_pred):.4f}")
print(f"MAE Score: {mean_absolute_error(y_test, y_pred):.4f}")
# Out:
# R2 Score: 0.2705
# MAE Score: 18162.8733

# %%
importances = pd.Series(RFR.feature_importances_, index=X.columns)
importances.sort_values().plot(kind='barh', color='steelblue')
plt.title('Feature importance - What drives rating_counts?')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.show()

# %%
print("""
=============================================================
        AMAZON SALES ANALYSIS - CONCLUSION SUMMARY
=============================================================

GOAL:
Analyze Amazon sales (estimated by rating_count) based on 
customer ratings, price, and discount.

-------------------------------------------------------------
KEY FINDINGS:
-------------------------------------------------------------

1. RATING DISTRIBUTION
   - Most products are rated between 3.5 and 4.5 stars
   - Very few products fall below 3.0

2. CORRELATION WITH SALES (rating_count)
   - Rating:              0.1022  (very weak)
   - Discounted Price:   -0.0273  (negligible)
   - Discount %:          0.0113  (negligible)
   → No single variable strongly predicts sales volume

3. FEATURE IMPORTANCE (Random Forest)
   - discounted_price:   ~0.29  (most important)
   - actual_price:       ~0.28
   - discount_percentage:~0.27
   - rating:             ~0.16  (least important)
   → Price matters more than rating for sales volume

4. MODEL PERFORMANCE
   - Linear Regression R²: 0.0047  (failed - linear 
     relationship does not exist)
   - Random Forest R²:     0.2705  (better, but limited)
   → 73% of sales variation is unexplained by available data

-------------------------------------------------------------
CONCLUSION:
-------------------------------------------------------------
Customer ratings alone are a poor predictor of Amazon sales.
Price-related features are stronger signals, but even 
combined they only explain 27% of sales volume variation.

The remaining 73% is likely driven by factors not present 
in this dataset such as:
   - Search ranking & visibility
   - Brand recognition
   - Time listed on platform
   - Prime eligibility
   - Advertising spend

A higher rating does NOT guarantee higher sales on Amazon.
=============================================================
""")
# Out:
# ...
#         AMAZON SALES ANALYSIS - CONCLUSION SUMMARY
# ...
#
# GOAL:
# Analyze Amazon sales (estimated by rating_count) based on
# customer ratings, price, and discount.
#
# -------------------------------------------------------------
# KEY FINDINGS:
# -------------------------------------------------------------
#
# 1. RATING DISTRIBUTION
#    - Most products are rated between 3.5 and 4.5 stars
#    - Very few products fall below 3.0
#
# 2. CORRELATION WITH SALES (rating_count)
#    - Rating:              0.1022  (very weak)
#    - Discounted Price:   -0.0273  (negligible)
#    - Discount %:          0.0113  (negligible)
#    → No single variable strongly predicts sales volume
#
# 3. FEATURE IMPORTANCE (Random Forest)
#    - discounted_price:   ~0.29  (most important)
#    - actual_price:       ~0.28
#    - discount_percentage:~0.27
#    - rating:             ~0.16  (least important)
#    → Price matters more than rating for sales volume
#
# 4. MODEL PERFORMANCE
# ...
